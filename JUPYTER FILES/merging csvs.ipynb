# %%
import numpy as np
import pandas as pd

# %%
# Define the path to the excel file
excel_file = r'F:\Janaki Data science folder\janu 2023\HomeLLC2023\Dataset\consolidated.xlsx'

# Specify the sheet names you want to read into DataFrames

sheet_names = ['HPI', 'CCI', 'CSENT','IRPI','CLI','LC_yearly','NUR','HS','DGDP','GDPGR']

# Create an empty list to store DataFrames
dfs = []

# Read each sheet into a DataFrame and append it to the list
for sheet_name in sheet_names:
    df = pd.read_excel(excel_file, sheet_name=sheet_name)
    dfs.append(df)

# Concatenate or append the DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)  # Use ignore_index=True to reset row indexes

# Now you have a single DataFrame 'combined_df' containing data from all sheets
combined_df
# Out:
#            DATE  HomePriceIndex  ConsumerConfidenceIndex ConsumerSentiment  \
# 0    1987-01-01          63.965                      NaN               NaN
# 1    1987-02-01          64.424                      NaN               NaN
# 2    1987-03-01          64.735                      NaN               NaN
# 3    1987-04-01          65.131                      NaN               NaN
# 4    1987-05-01          65.563                      NaN               NaN
# ...         ...             ...                      ...               ...
# 4932        NaT             NaN                      NaN               NaN
# 4933        NaT             NaN                      NaN               NaN
# 4934        NaT             NaN                      NaN               NaN
# 4935        NaT             NaN                      NaN               NaN
# 4936        NaT             NaN                      NaN               NaN
#
# ...

# %%
excel_file = r'F:\Janaki Data science folder\janu 2023\HomeLLC2023\Dataset\consolidated.xlsx'
df = pd.read_excel(excel_file, sheet_name='HPI')
df
# Out:
#           DATE  HomePriceIndex
# 0   1987-01-01          63.965
# 1   1987-02-01          64.424
# 2   1987-03-01          64.735
# 3   1987-04-01          65.131
# 4   1987-05-01          65.563
# ..         ...             ...
# 433 2023-02-01         296.958
# 434 2023-03-01         298.210
# 435 2023-04-01         300.214
# 436 2023-05-01         302.657
# 437 2023-06-01         304.635
#
# [438 rows x 2 columns]

# %%
df1 = pd.read_excel(excel_file, sheet_name='CCI')
df1.shape
# Out:
# (679, 2)

# %%
df1.columns
# Out:
# Index(['DATE', 'ConsumerConfidenceIndex'], dtype='object')

# %%
df2 = pd.read_excel(excel_file, sheet_name='CSENT')
print(df2.shape)
print(df2.columns)
# Out:
# (849, 2)
# Index(['DATE', 'ConsumerSentiment'], dtype='object')

# %%
df=df.merge(df1[['DATE', 'ConsumerConfidenceIndex']], on ='DATE', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex
# 0   1987-01-01          63.965                  112.300
# 1   1987-02-01          64.424                  112.700
# 2   1987-03-01          64.735                  113.000
# 3   1987-04-01          65.131                  113.500
# 4   1987-05-01          65.563                  113.800
# ..         ...             ...                      ...
# 433 2023-02-01         296.958                  315.732
# 434 2023-03-01         298.210                  316.667
# 435 2023-04-01         300.214                  317.414
# 436 2023-05-01         302.657                  318.193
# 437 2023-06-01         304.635                  319.154
#
# [438 rows x 3 columns]

# %%
df=df.merge(df2[['DATE', 'ConsumerSentiment']], on ='DATE', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex ConsumerSentiment
# 0   1987-01-01          63.965                  112.300              90.4
# 1   1987-02-01          64.424                  112.700              90.2
# 2   1987-03-01          64.735                  113.000              90.8
# 3   1987-04-01          65.131                  113.500              92.8
# 4   1987-05-01          65.563                  113.800              91.1
# ..         ...             ...                      ...               ...
# 433 2023-02-01         296.958                  315.732                67
# 434 2023-03-01         298.210                  316.667                62
# 435 2023-04-01         300.214                  317.414              63.5
# 436 2023-05-01         302.657                  318.193              59.2
# 437 2023-06-01         304.635                  319.154              64.4
#
# [438 rows x 4 columns]

# %%
df3 = pd.read_excel(excel_file, sheet_name='IRPI')
print(df3.shape)
print(df3.columns)
# Out:
# (129, 2)
# Index(['DATE', 'InterestRatesAndPriceIndexes'], dtype='object')

# %%
df=df.merge(df3[['DATE', 'InterestRatesAndPriceIndexes']], on ='DATE', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex ConsumerSentiment  \
# 0   1987-01-01          63.965                  112.300              90.4
# 1   1987-02-01          64.424                  112.700              90.2
# 2   1987-03-01          64.735                  113.000              90.8
# 3   1987-04-01          65.131                  113.500              92.8
# 4   1987-05-01          65.563                  113.800              91.1
# ..         ...             ...                      ...               ...
# 433 2023-02-01         296.958                  315.732                67
# 434 2023-03-01         298.210                  316.667                62
# 435 2023-04-01         300.214                  317.414              63.5
# 436 2023-05-01         302.657                  318.193              59.2
# 437 2023-06-01         304.635                  319.154              64.4
#
#      InterestRatesAndPriceIndexes
# 0                             NaN
# ...

# %%
df.tail(10)
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex ConsumerSentiment  \
# 428 2022-09-01         299.443                  306.129              58.6
# 429 2022-10-01         299.017                  307.881              59.9
# 430 2022-11-01         298.232                  309.328              56.8
# 431 2022-12-01         297.189                  311.629              59.7
# 432 2023-01-01         296.601                  314.039              64.9
# 433 2023-02-01         296.958                  315.732                67
# 434 2023-03-01         298.210                  316.667                62
# 435 2023-04-01         300.214                  317.414              63.5
# 436 2023-05-01         302.657                  318.193              59.2
# 437 2023-06-01         304.635                  319.154              64.4
#
#      InterestRatesAndPriceIndexes
# 428                           NaN
# 429                        6665.0
# 430                           NaN
# ...

# %%
df.isnull().sum()
# Out:
# DATE                              0
# HomePriceIndex                    0
# ConsumerConfidenceIndex           0
# ConsumerSentiment                 0
# InterestRatesAndPriceIndexes    309
# dtype: int64

# %%
# Forward fill NaN values in the DataFrame
df.fillna(method='ffill', inplace=True)
df.tail(10)
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 428 2022-09-01         299.443                  306.129               58.6
# 429 2022-10-01         299.017                  307.881               59.9
# 430 2022-11-01         298.232                  309.328               56.8
# 431 2022-12-01         297.189                  311.629               59.7
# 432 2023-01-01         296.601                  314.039               64.9
# 433 2023-02-01         296.958                  315.732               67.0
# 434 2023-03-01         298.210                  316.667               62.0
# 435 2023-04-01         300.214                  317.414               63.5
# 436 2023-05-01         302.657                  318.193               59.2
# 437 2023-06-01         304.635                  319.154               64.4
#
#      InterestRatesAndPriceIndexes
# 428                        5623.0
# 429                        6665.0
# 430                        6665.0
# ...

# %%
df4 = pd.read_excel(excel_file, sheet_name='CLI')
print(df4.shape)
print(df4.columns)
# Out:
# (403, 2)
# Index(['DATE', 'CompositeLeadingIndicator'], dtype='object')

# %%
df=df.merge(df4[['DATE', 'CompositeLeadingIndicator']], on ='DATE', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0   1987-01-01          63.965                  112.300               90.4
# 1   1987-02-01          64.424                  112.700               90.2
# 2   1987-03-01          64.735                  113.000               90.8
# 3   1987-04-01          65.131                  113.500               92.8
# 4   1987-05-01          65.563                  113.800               91.1
# ..         ...             ...                      ...                ...
# 433 2023-02-01         296.958                  315.732               67.0
# 434 2023-03-01         298.210                  316.667               62.0
# 435 2023-04-01         300.214                  317.414               63.5
# 436 2023-05-01         302.657                  318.193               59.2
# 437 2023-06-01         304.635                  319.154               64.4
#
#      InterestRatesAndPriceIndexes  CompositeLeadingIndicator
# ...

# %%
#selecting data from 1990
df=df.loc[lambda x:x['DATE']>='1990-01-01',:].reset_index(drop=True)
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0   1990-01-01          76.897                  126.100               93.0
# 1   1990-02-01          77.053                  126.200               89.5
# 2   1990-03-01          77.201                  126.800               91.3
# 3   1990-04-01          77.278                  127.100               93.9
# 4   1990-05-01          77.297                  127.300               90.6
# ..         ...             ...                      ...                ...
# 397 2023-02-01         296.958                  315.732               67.0
# 398 2023-03-01         298.210                  316.667               62.0
# 399 2023-04-01         300.214                  317.414               63.5
# 400 2023-05-01         302.657                  318.193               59.2
# 401 2023-06-01         304.635                  319.154               64.4
#
#      InterestRatesAndPriceIndexes  CompositeLeadingIndicator
# ...

# %%
# backward fill NaN values in the DataFrame
df.fillna(method='bfill', inplace=True)
df.head()
# Out:
#         DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0 1990-01-01          76.897                    126.1               93.0
# 1 1990-02-01          77.053                    126.2               89.5
# 2 1990-03-01          77.201                    126.8               91.3
# 3 1990-04-01          77.278                    127.1               93.9
# 4 1990-05-01          77.297                    127.3               90.6
#
#    InterestRatesAndPriceIndexes  CompositeLeadingIndicator
# 0                        9501.0                  99.793618
# 1                        9501.0                  99.824087
# 2                        9501.0                  99.821915
# 3                        9501.0                  99.742223
# 4                        9501.0                  99.565870

# %%
df5 = pd.read_excel(excel_file, sheet_name='LC_yearly')
print(df5.shape)
print(df5.columns)
# Out:
# (35, 2)
# Index(['DATE', 'LaborCost'], dtype='object')

# %%
df=df.merge(df5[['DATE', 'LaborCost']], on ='DATE', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0   1990-01-01          76.897                  126.100               93.0
# 1   1990-02-01          77.053                  126.200               89.5
# 2   1990-03-01          77.201                  126.800               91.3
# 3   1990-04-01          77.278                  127.100               93.9
# 4   1990-05-01          77.297                  127.300               90.6
# ..         ...             ...                      ...                ...
# 397 2023-02-01         296.958                  315.732               67.0
# 398 2023-03-01         298.210                  316.667               62.0
# 399 2023-04-01         300.214                  317.414               63.5
# 400 2023-05-01         302.657                  318.193               59.2
# 401 2023-06-01         304.635                  319.154               64.4
#
# ...

# %%
# forward fill NaN values in the DataFrame
df.fillna(method='ffill', inplace=True)
df.head()
# Out:
#         DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0 1990-01-01          76.897                    126.1               93.0
# 1 1990-02-01          77.053                    126.2               89.5
# 2 1990-03-01          77.201                    126.8               91.3
# 3 1990-04-01          77.278                    127.1               93.9
# 4 1990-05-01          77.297                    127.3               90.6
#
#    InterestRatesAndPriceIndexes  CompositeLeadingIndicator  LaborCost
# 0                        9501.0                  99.793618        1.3
# 1                        9501.0                  99.824087        1.3
# 2                        9501.0                  99.821915        1.3
# 3                        9501.0                  99.742223        1.3
# 4                        9501.0                  99.565870        1.3

# %%
df6 = pd.read_excel(excel_file, sheet_name='NUR')
print(df6.shape)
print(df6.columns)
# Out:
# (908, 2)
# Index(['DATE', 'NationalUnemploymentRate'], dtype='object')

# %%
df=df.merge(df6[['DATE', 'NationalUnemploymentRate']], on ='DATE', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0   1990-01-01          76.897                  126.100               93.0
# 1   1990-02-01          77.053                  126.200               89.5
# 2   1990-03-01          77.201                  126.800               91.3
# 3   1990-04-01          77.278                  127.100               93.9
# 4   1990-05-01          77.297                  127.300               90.6
# ..         ...             ...                      ...                ...
# 397 2023-02-01         296.958                  315.732               67.0
# 398 2023-03-01         298.210                  316.667               62.0
# 399 2023-04-01         300.214                  317.414               63.5
# 400 2023-05-01         302.657                  318.193               59.2
# 401 2023-06-01         304.635                  319.154               64.4
#
# ...

# %%
df7 = pd.read_excel(excel_file, sheet_name='HS')
print(df7.shape)
print(df7.columns)
# Out:
# (775, 2)
# Index(['DATE', 'HousingStarts'], dtype='object')

# %%
df=df.merge(df7[['DATE', 'HousingStarts']], on ='DATE', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0   1990-01-01          76.897                  126.100               93.0
# 1   1990-02-01          77.053                  126.200               89.5
# 2   1990-03-01          77.201                  126.800               91.3
# 3   1990-04-01          77.278                  127.100               93.9
# 4   1990-05-01          77.297                  127.300               90.6
# ..         ...             ...                      ...                ...
# 397 2023-02-01         296.958                  315.732               67.0
# 398 2023-03-01         298.210                  316.667               62.0
# 399 2023-04-01         300.214                  317.414               63.5
# 400 2023-05-01         302.657                  318.193               59.2
# 401 2023-06-01         304.635                  319.154               64.4
#
# ...

# %%
df8 = pd.read_excel(excel_file, sheet_name='DGDP')
print(df8.shape)
print(df8.columns)
# Out:
# (688, 2)
# Index(['DATE', 'DebtToGDPRatio'], dtype='object')

# %%
df=df.merge(df8[['DATE', 'DebtToGDPRatio']], on ='DATE', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0   1990-01-01          76.897                  126.100               93.0
# 1   1990-02-01          77.053                  126.200               89.5
# 2   1990-03-01          77.201                  126.800               91.3
# 3   1990-04-01          77.278                  127.100               93.9
# 4   1990-05-01          77.297                  127.300               90.6
# ..         ...             ...                      ...                ...
# 397 2023-02-01         296.958                  315.732               67.0
# 398 2023-03-01         298.210                  316.667               62.0
# 399 2023-04-01         300.214                  317.414               63.5
# 400 2023-05-01         302.657                  318.193               59.2
# 401 2023-06-01         304.635                  319.154               64.4
#
# ...

# %%
df9 = pd.read_excel(excel_file, sheet_name='GDPGR')
print(df9.shape)
print(df9.columns)
# Out:
# (33, 2)
# Index(['Year', 'GDPGrowthRate'], dtype='object')

# %%
# Create a new column "year" by extracting the year from the "date" column
df['Year'] = df['DATE'].dt.year
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0   1990-01-01          76.897                  126.100               93.0
# 1   1990-02-01          77.053                  126.200               89.5
# 2   1990-03-01          77.201                  126.800               91.3
# 3   1990-04-01          77.278                  127.100               93.9
# 4   1990-05-01          77.297                  127.300               90.6
# ..         ...             ...                      ...                ...
# 397 2023-02-01         296.958                  315.732               67.0
# 398 2023-03-01         298.210                  316.667               62.0
# 399 2023-04-01         300.214                  317.414               63.5
# 400 2023-05-01         302.657                  318.193               59.2
# 401 2023-06-01         304.635                  319.154               64.4
#
# ...

# %%
df=df.merge(df9[['Year', 'GDPGrowthRate']], on ='Year', how="left")
df
# Out:
#           DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0   1990-01-01          76.897                  126.100               93.0
# 1   1990-02-01          77.053                  126.200               89.5
# 2   1990-03-01          77.201                  126.800               91.3
# 3   1990-04-01          77.278                  127.100               93.9
# 4   1990-05-01          77.297                  127.300               90.6
# ..         ...             ...                      ...                ...
# 397 2023-02-01         296.958                  315.732               67.0
# 398 2023-03-01         298.210                  316.667               62.0
# 399 2023-04-01         300.214                  317.414               63.5
# 400 2023-05-01         302.657                  318.193               59.2
# 401 2023-06-01         304.635                  319.154               64.4
#
# ...

# %%
# forward fill NaN values in the DataFrame
df.fillna(method='ffill', inplace=True)
df.head()
# Out:
#         DATE  HomePriceIndex  ConsumerConfidenceIndex  ConsumerSentiment  \
# 0 1990-01-01          76.897                    126.1               93.0
# 1 1990-02-01          77.053                    126.2               89.5
# 2 1990-03-01          77.201                    126.8               91.3
# 3 1990-04-01          77.278                    127.1               93.9
# 4 1990-05-01          77.297                    127.3               90.6
#
#    InterestRatesAndPriceIndexes  CompositeLeadingIndicator  LaborCost  \
# 0                        9501.0                  99.793618        1.3
# 1                        9501.0                  99.824087        1.3
# 2                        9501.0                  99.821915        1.3
# 3                        9501.0                  99.742223        1.3
# 4                        9501.0                  99.565870        1.3
#
#    NationalUnemploymentRate  HousingStarts  DebtToGDPRatio  Year  \
# ...

# %%
df.isnull().sum()
# Out:
# DATE                            0
# HomePriceIndex                  0
# ConsumerConfidenceIndex         0
# ConsumerSentiment               0
# InterestRatesAndPriceIndexes    0
# CompositeLeadingIndicator       0
# LaborCost                       0
# NationalUnemploymentRate        0
# HousingStarts                   0
# DebtToGDPRatio                  0
# Year                            0
# GDPGrowthRate                   0
# dtype: int64

# %%
df.to_csv('all_data_file.csv', index=False)

# %%
df10 = pd.read_csv("JupyterLab folders/HomeLLCSep23/consolidated_permit_confidence.csv")
print(df10.shape)
print(df10.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9536\3013661347.py in <module>
# ----> 1 df10 = pd.read_csv("JupyterLab folders/HomeLLCSep23/consolidated_permit_confidence.csv")
#       2 print(df10.shape)
#       3 print(df10.columns)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
